# %% [markdown]
# <a href="https://colab.research.google.com/github/Ameen740/Internship_Flyrank/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ameen740/Internship_Flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# My lane is Refresh / Content Opportunity Scoring. I chose this lane because it focuses on helping prioritize which content pages should be reviewed first based on observable search and engagement signals. Instead of relying on fixed rules, I will build and evaluate a ranking system that supports content review decisions using evidence from the data. This lane matches my interest in machine learning, feature engineering, and decision-support systems.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# This project improves the decision of which content pages should be reviewed first. The output will be used by content editors or SEO teams to prioritize their work. Based on the ranked recommendations, they can decide whether to refresh, expand, protect, monitor, or prune a page. A wrong recommendation may cause valuable review time to be spent on low-priority pages while important pages that genuinely need attention are overlooked.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
#
# The starter dataset contains 30,000 content items across 32 pseudonymized clients with 44 columns of observable search and engagement signals. This provides enough data to explore ranking methods, build baseline scores, and compare machine learning models for content opportunity scoring.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Unique clients:", df["client_id"].nunique())
# Out:
# Rows: 30000
# Columns: 44
# Unique clients: 32

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project provides decision-support by identifying pages that may deserve review based on observed search and engagement signals. The recommendations are based on measured patterns in the available data and should be interpreted as evidence for prioritization rather than proof of future outcomes. This project does not prove that refreshing a page will improve performance, nor does it claim to identify Google's ranking factors or establish causal relationships.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
